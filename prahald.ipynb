# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\rishi\ml_projects\Applied-AI-in-Finance\Sapm\data - Sheet1.csv")
df
age=df['Age'].to_numpy()
activity=df['Physical Activity Level'].to_numpy()
heart_rate=df['Heart Rate'].to_numpy()
stress_level=df['Stress Level'].to_numpy()

y_vals=[]
for i in range(len(age)):
    temp=[age[i],activity[i],heart_rate[i]]
    y_vals.append(temp)
y_vals

model=LinearRegression()
model.fit(y_vals,stress_level)
model.coef_[0]

print(f"age :{model.coef_[0]}, activity : {model.coef_[1]}, heart_rate: {model.coef_[2]}")
# Out:
#      Gender  Age   BMI Category  Physical Activity Level  Heart Rate  \
# 0      Male   16         Normal                       75          70
# 1      Male   21         Normal                       75          70
# 2      Male   23         Normal                       30          72
# 3      Male   22         Normal                       30          72
# 4    Female   28  Normal Weight                       60          70
# ..      ...  ...            ...                      ...         ...
# 181  Female   30  Normal Weight                       35          78
# 182    Male   33         Normal                       30          72
# 183    Male   32         Normal                       30          72
# 184    Male   29         Normal                       30          70
# 185    Male   20         Normal                       60          68
#
#      Stress Level
# 0               6
# 1               6
# 2               8
# 3               8
# 4               4
# ..            ...
# 181             7
# 182             8
# 183             8
# 184             8
# 185             5
#
# [186 rows x 6 columns]
