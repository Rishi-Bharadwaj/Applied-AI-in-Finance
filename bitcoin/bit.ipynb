# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt 
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from torch.utils.data import TensorDataset,DataLoader

# %%
df=pd.read_csv(r"C:\Users\rishi\ml_projects\bitcoin\BTC-USD.csv")
print(df[-10:])
# Out:
#             Date          Open          High           Low         Close  \
# 1817  2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 1818  2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# 1819  2024-01-06  44178.953125  44227.632813  43475.156250  43989.195313
# 1820  2024-01-07  43998.464844  44495.570313  43662.230469  43943.097656
# 1821  2024-01-08  43948.707031  47218.000000  43244.082031  46970.503906
# 1822  2024-01-09  46987.640625  47893.699219  45244.714844  46139.730469
# 1823  2024-01-10  46121.539063  47647.222656  44483.152344  46627.777344
# 1824  2024-01-11  46656.074219  48969.371094  45678.644531  46368.585938
# 1825  2024-01-12  46354.792969  46498.136719  41903.769531  42853.167969
# 1826  2024-01-13  42799.445313  43234.660156  42464.460938  42587.582031
#
#          Adj Close       Volume
# 1817  44179.921875  30448091210
# 1818  44162.691406  32336029347
# 1819  43989.195313  16092503468
# 1820  43943.097656  19330573863
# ...

# %%
plt.plot(range(len(df['Close'])),df['Close'],'r')
fig=plt.figure()
plt.plot(range(len(df['Volume'])),df['Volume'],'g')

# %%
scalar=StandardScaler()
nodate=df.drop(["Date",'Close'],axis=1)
print(nodate.head())
nodate_trans=scalar.fit_transform(nodate)

nodate_trans=torch.tensor(nodate_trans)

nodate_trans=TensorDataset(nodate_trans)
print(nodate_trans[0])
# Out:
#           Open         High          Low    Adj Close      Volume
# 0  3658.868164  3674.760010  3544.927246  3552.953125  4681302466
# 1  3557.311035  3727.836182  3552.285156  3706.052246  5651384490
# 2  3704.216309  3720.153320  3619.949219  3630.675293  5537192302
# 3  3631.509766  3685.777100  3624.673340  3655.006836  5394457145
# 4  3651.871094  3680.135986  3621.960938  3678.563965  5464420383
# (tensor([-1.3196, -1.3203, -1.3280, -1.3279, -1.3596], dtype=torch.float64),)
