# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
np.random.seed(4)

risk_free_rate=.0687
tickers = "SPY BTC-USD BANDHANBNK.NS GILLETTE.NS NCC.NS FORTIS.NS RECLTD.NS DIVISLAB.NS COROMANDEL.NS"
start_date = "2023-01-01"
end_date = "2023-12-31"
data = yf.download(tickers, start=start_date, end=end_date)
data
# Out:
# [*********************100%***********************]  9 of 9 completed
# Price                         Adj Close                              \
# Ticker                    BANDHANBNK.NS       BTC-USD COROMANDEL.NS
# Date
# 2023-01-01 00:00:00+00:00           NaN  16625.080078           NaN
# 2023-01-02 00:00:00+00:00    236.759491  16688.470703    877.051392
# 2023-01-03 00:00:00+00:00    237.153839  16679.857422    880.080872
# 2023-01-04 00:00:00+00:00    236.710190  16863.238281    875.047974
# 2023-01-05 00:00:00+00:00    237.104553  16836.736328    882.133240
# ...                                 ...           ...           ...
# 2023-12-26 00:00:00+00:00    233.161484  42520.402344   1258.540527
# 2023-12-27 00:00:00+00:00    236.188278  43442.855469   1238.066406
# 2023-12-28 00:00:00+00:00    237.528000  42627.855469   1235.177124
# 2023-12-29 00:00:00+00:00    239.562393  42099.402344   1247.033203
# 2023-12-30 00:00:00+00:00           NaN  42156.902344           NaN
#
# Price                                                                        \
# Ticker                     DIVISLAB.NS   FORTIS.NS  GILLETTE.NS      NCC.NS
# Date
# 2023-01-01 00:00:00+00:00          NaN         NaN          NaN         NaN
# 2023-01-02 00:00:00+00:00  3298.538086  280.516174  4899.134766   88.490479
# 2023-01-03 00:00:00+00:00  3318.440918  282.157806  4908.235840   87.477234
# 2023-01-04 00:00:00+00:00  3360.055908  281.809570  4921.987305   87.959732
# 2023-01-05 00:00:00+00:00  3385.778076  285.639984  4911.955566   89.986244
# ...                                ...         ...          ...         ...
# 2023-12-26 00:00:00+00:00  3839.931885  395.286987  6060.233398  166.348083
# 2023-12-27 00:00:00+00:00  3860.555420  399.378571  6071.409668  167.241882
# 2023-12-28 00:00:00+00:00  3915.915527  404.468079  6507.246582  165.603241
# 2023-12-29 00:00:00+00:00  3880.085449  418.339600  6440.435547  165.603241
# 2023-12-30 00:00:00+00:00          NaN         NaN          NaN         NaN
#
# Price                                                     Close  ...  \
# Ticker                      RECLTD.NS         SPY BANDHANBNK.NS  ...
# Date                                                             ...
# 2023-01-01 00:00:00+00:00         NaN         NaN           NaN  ...
# 2023-01-02 00:00:00+00:00  108.514374         NaN    240.149994  ...
# 2023-01-03 00:00:00+00:00  110.857712  371.614441    240.550003  ...
# 2023-01-04 00:00:00+00:00  110.136681  374.483337    240.100006  ...
# 2023-01-05 00:00:00+00:00  111.623802  370.209229    240.500000  ...
# ...                               ...         ...           ...  ...
# 2023-12-26 00:00:00+00:00  408.353302  471.206573    234.949997  ...
# 2023-12-27 00:00:00+00:00  400.069305  472.058533    238.000000  ...
# 2023-12-28 00:00:00+00:00  399.825653  472.236847    239.350006  ...
# 2023-12-29 00:00:00+00:00  402.359589  470.869720    241.399994  ...
# 2023-12-30 00:00:00+00:00         NaN         NaN           NaN  ...
#
# Price                            Open        Volume               \
# Ticker                            SPY BANDHANBNK.NS      BTC-USD
# Date
# 2023-01-01 00:00:00+00:00         NaN           NaN   9244361700
# 2023-01-02 00:00:00+00:00         NaN     7625641.0  12097775227
# 2023-01-03 00:00:00+00:00  384.369995     6273607.0  13903079207
# 2023-01-04 00:00:00+00:00  383.179993    10555612.0  18421743322
# 2023-01-05 00:00:00+00:00  381.720001     8344344.0  13692758566
# ...                               ...           ...          ...
# 2023-12-26 00:00:00+00:00  474.070007     6304183.0  30026850982
# 2023-12-27 00:00:00+00:00  475.440002     8058617.0  25260941032
# 2023-12-28 00:00:00+00:00  476.880005    12591185.0  22992093014
# 2023-12-29 00:00:00+00:00  476.489990     4590031.0  26000021055
# 2023-12-30 00:00:00+00:00         NaN           NaN  16013925945
#
# Price                                                                       \
# Ticker                    COROMANDEL.NS DIVISLAB.NS  FORTIS.NS GILLETTE.NS
# Date
# 2023-01-01 00:00:00+00:00           NaN         NaN        NaN         NaN
# 2023-01-02 00:00:00+00:00      396209.0    283161.0   287492.0       988.0
# 2023-01-03 00:00:00+00:00      335419.0    244677.0   280865.0      1001.0
# 2023-01-04 00:00:00+00:00      459211.0    365514.0   678732.0      1091.0
# 2023-01-05 00:00:00+00:00      729644.0    270647.0   745831.0      1559.0
# ...                                 ...         ...        ...         ...
# 2023-12-26 00:00:00+00:00      175434.0   1249185.0  1483447.0     10504.0
# 2023-12-27 00:00:00+00:00     1243304.0    598775.0   979146.0     24950.0
# 2023-12-28 00:00:00+00:00      483996.0    668311.0  1222326.0     79070.0
# 2023-12-29 00:00:00+00:00      211474.0    262845.0  2396214.0     22772.0
# 2023-12-30 00:00:00+00:00           NaN         NaN        NaN         NaN
#
# Price
# Ticker                         NCC.NS   RECLTD.NS          SPY
# Date
# 2023-01-01 00:00:00+00:00         NaN         NaN          NaN
# 2023-01-02 00:00:00+00:00  41827634.0  19310744.0          NaN
# 2023-01-03 00:00:00+00:00   8301442.0  27524213.0   74850700.0
# 2023-01-04 00:00:00+00:00  11986335.0  14375149.0   85934100.0
# 2023-01-05 00:00:00+00:00  12283099.0   9774790.0   76970500.0
# ...                               ...         ...          ...
# 2023-12-26 00:00:00+00:00   3351519.0  13481039.0   55387000.0
# 2023-12-27 00:00:00+00:00   4127661.0   9149448.0   68000300.0
# 2023-12-28 00:00:00+00:00   2552902.0   8028672.0   77158100.0
# 2023-12-29 00:00:00+00:00   1960783.0   6932668.0  122234100.0
# 2023-12-30 00:00:00+00:00         NaN         NaN          NaN
#
# [364 rows x 54 columns]

# %%
df=data[[('Adj Close', 'BANDHANBNK.NS'),
         ('Adj Close', 'COROMANDEL.NS'),
            ('Adj Close',   'DIVISLAB.NS'),
            ('Adj Close',     'FORTIS.NS'),
            ('Adj Close',   'GILLETTE.NS'),
            ('Adj Close',        'NCC.NS'),
            ('Adj Close',     'RECLTD.NS'),]]
df.dropna(inplace=True)
df
# Out:
# Price                         Adj Close                             \
# Ticker                    BANDHANBNK.NS COROMANDEL.NS  DIVISLAB.NS
# Date
# 2023-01-02 00:00:00+00:00    236.759491    877.051392  3298.538086
# 2023-01-03 00:00:00+00:00    237.153839    880.080872  3318.440918
# 2023-01-04 00:00:00+00:00    236.710190    875.047974  3360.055908
# 2023-01-05 00:00:00+00:00    237.104553    882.133240  3385.778076
# 2023-01-06 00:00:00+00:00    238.928436    881.253662  3359.419922
# ...                                 ...           ...          ...
# 2023-12-22 00:00:00+00:00    233.012634   1226.509277  3672.410156
# 2023-12-26 00:00:00+00:00    233.161484   1258.540527  3839.931885
# 2023-12-27 00:00:00+00:00    236.188278   1238.066406  3860.555420
# 2023-12-28 00:00:00+00:00    237.528000   1235.177124  3915.915527
# 2023-12-29 00:00:00+00:00    239.562393   1247.033203  3880.085449
#
# Price
# Ticker                      FORTIS.NS  GILLETTE.NS      NCC.NS   RECLTD.NS
# Date
# 2023-01-02 00:00:00+00:00  280.516174  4899.134766   88.490479  108.514374
# 2023-01-03 00:00:00+00:00  282.157806  4908.235840   87.477234  110.857712
# 2023-01-04 00:00:00+00:00  281.809570  4921.987305   87.959732  110.136681
# 2023-01-05 00:00:00+00:00  285.639984  4911.955566   89.986244  111.623802
# 2023-01-06 00:00:00+00:00  283.401459  4890.032715   90.854736  111.488602
# ...                               ...          ...         ...         ...
# 2023-12-22 00:00:00+00:00  389.898071  6100.717285  162.872147  396.268372
# 2023-12-26 00:00:00+00:00  395.286987  6060.233398  166.348083  408.353302
# 2023-12-27 00:00:00+00:00  399.378571  6071.409668  167.241882  400.069305
# 2023-12-28 00:00:00+00:00  404.468079  6507.246582  165.603241  399.825653
# 2023-12-29 00:00:00+00:00  418.339600  6440.435547  165.603241  402.359589
#
# [245 rows x 7 columns]

# %%
returns = np.log(df / df.shift(1)).dropna()
returns.columns = returns.columns.get_level_values(1)
mean_returns = returns.mean()
annualised_mean_returns=(1+mean_returns)**252 -1
annualised_mean_returns
# Out:
# Ticker
# BANDHANBNK.NS    0.012229
# COROMANDEL.NS    0.437973
# DIVISLAB.NS      0.182518
# FORTIS.NS        0.510481
# GILLETTE.NS      0.326240
# NCC.NS           0.908691
# RECLTD.NS        2.856685
# dtype: float64

# %%
df['Adj Close'].plot(figsize=(12, 6), title='Stock Prices', xlabel='Date', ylabel='Price')
# Out:
# <Axes: title={'center': 'Stock Prices'}, xlabel='Date', ylabel='Price'>

# %%
cov_matrix = returns.cov()
cov_matrix*252
# Out:
# Ticker         BANDHANBNK.NS  COROMANDEL.NS  DIVISLAB.NS  FORTIS.NS  \
# Ticker
# BANDHANBNK.NS       0.081152       0.018721     0.007626   0.007744
# COROMANDEL.NS       0.018721       0.045810     0.010743   0.004255
# DIVISLAB.NS         0.007626       0.010743     0.076221   0.010158
# FORTIS.NS           0.007744       0.004255     0.010158   0.052628
# GILLETTE.NS         0.000314       0.004850     0.006630   0.006411
# NCC.NS              0.016888       0.015303    -0.003391   0.004748
# RECLTD.NS           0.031540       0.019894     0.002942   0.012487
#
# Ticker         GILLETTE.NS    NCC.NS  RECLTD.NS
# Ticker
# BANDHANBNK.NS     0.000314  0.016888   0.031540
# COROMANDEL.NS     0.004850  0.015303   0.019894
# DIVISLAB.NS       0.006630 -0.003391   0.002942
# FORTIS.NS         0.006411  0.004748   0.012487
# GILLETTE.NS       0.051826  0.001584   0.002008
# NCC.NS            0.001584  0.162194   0.039678
# RECLTD.NS         0.002008  0.039678   0.132511

# %%
variance=returns.var()
variance
annualised_variance=variance*252
standard_deviation=np.sqrt(annualised_variance)
standard_deviation
# Out:
# Ticker
# BANDHANBNK.NS    0.284872
# COROMANDEL.NS    0.214033
# DIVISLAB.NS      0.276082
# FORTIS.NS        0.229408
# GILLETTE.NS      0.227654
# NCC.NS           0.402733
# RECLTD.NS        0.364021
# dtype: float64

# %% [markdown]
# ## Equally Weighted Portfolio

# %%
x=1/7
weights=np.array([x for i in range(0,7)])
weights
portfolio_return=np.dot(annualised_mean_returns,weights)
portfolio_return
portfolio_variance = np.dot(weights.T, np.dot(cov_matrix, weights))*252
portfolio_variance
portfolio_risk=np.sqrt(portfolio_variance)

portfolio_variance
# Out:
# 0.021318483566713523

# %%
portfolio_risk
# Out:
# 0.14600850511772773

# %%
portfolio_return
# Out:
# 0.7478309738798414

# %%
Sharpe_ratio=portfolio_return-risk_free_rate
Sharpe_ratio=Sharpe_ratio/portfolio_risk
Sharpe_ratio
# Out:
# 4.65131105432696

# %% [markdown]
# ## Minimum Variance Portfolio

# %%
def make_random_portfolio(n,returns, covariance_matrix):
    random_weights=np.random.rand(n)-0.5
    random_weights=random_weights/np.sum(random_weights)
    portfolio_return=np.dot(random_weights,returns)
    portfolio_variance=np.dot(random_weights.T,np.dot(covariance_matrix,random_weights))*252

    return random_weights,portfolio_return,portfolio_variance

# %%
min_variance=100
er=[]
sigma=[]
sharpe_ratio=0
min_weights=np.ones(7)
for i in range(0,100000):
    x,y,z=make_random_portfolio(7,annualised_mean_returns,cov_matrix)
    er.append(y)
    sigma.append(np.sqrt(z))
    if(z<min_variance):
        min_variance=z
        min_weights=x
        min_return=y
    sharpe_temp=(y-risk_free_rate)/np.sqrt(z)
    if(sharpe_temp>sharpe_ratio):
        sharpe_ratio=sharpe_temp
        sharpe_weights=x
        sharpe_return=y
        sharpe_variance=z

# %%
print(f"min_var_weights: {min_weights}")
print(f"min_var_return: {min_return}")
print(f"min_variance: {min_variance}")
print(f"max_sharpe_ratio: {sharpe_ratio}")
print(f"max_sharpe_weights: {sharpe_weights}")
print(f"max_sharpe_return: {sharpe_return}")
print(f"max_sharpe_variance: {sharpe_variance}")
# Out:
# min_var_weights: [ 0.16579046  0.14154232  0.11733231  0.26376909  0.25490653  0.06452925
#  -0.00786996]
# min_var_return: 0.33939933220983254
# min_variance: 0.017272458593679485
# max_sharpe_ratio: 8.034983809233452
# max_sharpe_weights: [-0.63044912  0.15996022  0.00833447  0.46603642 -0.00777082 -0.02762904
#   1.03151787]
# max_sharpe_return: 3.2208529911551693
# max_sharpe_variance: 0.1539021064535699

# %% [markdown]
# ## Efficient Frontier and Tangency Portfolio

# %%
plt.figure(figsize=(10,10))
plt.scatter(sigma,er)
plt.scatter(np.sqrt(sharpe_variance),sharpe_return,c="r")
plt.scatter(np.sqrt(min_variance),min_return, c='y')


plt.annotate('Tangency Portfolio', 
             xy=(np.sqrt(sharpe_variance),sharpe_return), 
             xytext=(np.sqrt(sharpe_variance) + 0.01,sharpe_return + 0.01),
             fontsize=10)

plt.annotate('Minimum Variance', 
             xy=(np.sqrt(min_variance),min_return), 
             xytext=(np.sqrt(min_variance) + 0.01,min_return + 0.01),
             fontsize=10)

x = np.linspace(0, max(sigma), 100)
y = risk_free_rate + sharpe_ratio * x
plt.title("Efficient Frontier and Tangency Portfolio, Domestic")
plt.xlabel('Portfolio Risk (Standard Deviation)')
plt.ylabel('Portfolio Return')
plt.plot(x,y,c='purple',label='CAL',linewidth=2)
plt.legend()

# %% [markdown]
# # International Portfolio with SPY

# %%
df=data[[('Adj Close', 'BANDHANBNK.NS'),
            ('Adj Close', 'COROMANDEL.NS'),
            ('Adj Close',   'DIVISLAB.NS'),
            ('Adj Close',     'FORTIS.NS'),
            ('Adj Close',   'GILLETTE.NS'),
            ('Adj Close',        'NCC.NS'),
            ('Adj Close',     'RECLTD.NS'),
            ('Adj Close',           'SPY'),]]
df.dropna(inplace=True)
df
# Out:
# Price                         Adj Close                             \
# Ticker                    BANDHANBNK.NS COROMANDEL.NS  DIVISLAB.NS
# Date
# 2023-01-03 00:00:00+00:00    237.153839    880.080872  3318.440918
# 2023-01-04 00:00:00+00:00    236.710190    875.047974  3360.055908
# 2023-01-05 00:00:00+00:00    237.104553    882.133240  3385.778076
# 2023-01-06 00:00:00+00:00    238.928436    881.253662  3359.419922
# 2023-01-09 00:00:00+00:00    243.759247    878.615051  3383.479736
# ...                                 ...           ...          ...
# 2023-12-22 00:00:00+00:00    233.012634   1226.509277  3672.410156
# 2023-12-26 00:00:00+00:00    233.161484   1258.540527  3839.931885
# 2023-12-27 00:00:00+00:00    236.188278   1238.066406  3860.555420
# 2023-12-28 00:00:00+00:00    237.528000   1235.177124  3915.915527
# 2023-12-29 00:00:00+00:00    239.562393   1247.033203  3880.085449
#
# Price                                                                       \
# Ticker                      FORTIS.NS  GILLETTE.NS      NCC.NS   RECLTD.NS
# Date
# 2023-01-03 00:00:00+00:00  282.157806  4908.235840   87.477234  110.857712
# 2023-01-04 00:00:00+00:00  281.809570  4921.987305   87.959732  110.136681
# 2023-01-05 00:00:00+00:00  285.639984  4911.955566   89.986244  111.623802
# 2023-01-06 00:00:00+00:00  283.401459  4890.032715   90.854736  111.488602
# 2023-01-09 00:00:00+00:00  285.789246  4872.661133   90.275734  113.155975
# ...                               ...          ...         ...         ...
# 2023-12-22 00:00:00+00:00  389.898071  6100.717285  162.872147  396.268372
# 2023-12-26 00:00:00+00:00  395.286987  6060.233398  166.348083  408.353302
# 2023-12-27 00:00:00+00:00  399.378571  6071.409668  167.241882  400.069305
# 2023-12-28 00:00:00+00:00  404.468079  6507.246582  165.603241  399.825653
# 2023-12-29 00:00:00+00:00  418.339600  6440.435547  165.603241  402.359589
#
# Price
# Ticker                            SPY
# Date
# 2023-01-03 00:00:00+00:00  371.614441
# 2023-01-04 00:00:00+00:00  374.483337
# 2023-01-05 00:00:00+00:00  370.209229
# 2023-01-06 00:00:00+00:00  378.698883
# 2023-01-09 00:00:00+00:00  378.484192
# ...                               ...
# 2023-12-22 00:00:00+00:00  469.225250
# 2023-12-26 00:00:00+00:00  471.206573
# 2023-12-27 00:00:00+00:00  472.058533
# 2023-12-28 00:00:00+00:00  472.236847
# 2023-12-29 00:00:00+00:00  470.869720
#
# [237 rows x 8 columns]

# %%
returns = np.log(df / df.shift(1)).dropna()
returns.columns = returns.columns.get_level_values(1)
mean_returns = returns.mean()
annualised_mean_returns=(1+mean_returns)**252 -1
annualised_mean_returns
# Out:
# Ticker
# BANDHANBNK.NS    0.010848
# COROMANDEL.NS    0.450433
# DIVISLAB.NS      0.181645
# FORTIS.NS        0.522230
# GILLETTE.NS      0.336339
# NCC.NS           0.974994
# RECLTD.NS        2.946186
# SPY              0.287429
# dtype: float64

# %%
cov_matrix = returns.cov()
cov_matrix*252
# Out:
# Ticker         BANDHANBNK.NS  COROMANDEL.NS  DIVISLAB.NS  FORTIS.NS  \
# Ticker
# BANDHANBNK.NS       0.085461       0.019657     0.006365   0.006987
# COROMANDEL.NS       0.019657       0.047824     0.010484   0.004005
# DIVISLAB.NS         0.006365       0.010484     0.077878   0.011238
# FORTIS.NS           0.006987       0.004005     0.011238   0.055398
# GILLETTE.NS         0.000122       0.005003     0.006428   0.006192
# NCC.NS              0.017650       0.015352    -0.004203   0.005161
# RECLTD.NS           0.032792       0.021629     0.002000   0.011497
# SPY                -0.000936      -0.000090     0.001765   0.000745
#
# Ticker         GILLETTE.NS    NCC.NS  RECLTD.NS       SPY
# Ticker
# BANDHANBNK.NS     0.000122  0.017650   0.032792 -0.000936
# COROMANDEL.NS     0.005003  0.015352   0.021629 -0.000090
# DIVISLAB.NS       0.006428 -0.004203   0.002000  0.001765
# FORTIS.NS         0.006192  0.005161   0.011497  0.000745
# GILLETTE.NS       0.053383  0.002037   0.001845 -0.000437
# NCC.NS            0.002037  0.164530   0.042496  0.003698
# RECLTD.NS         0.001845  0.042496   0.137215  0.003359
# SPY              -0.000437  0.003698   0.003359  0.018444

# %%
variance=returns.var()
variance
annualised_variance=variance*252
standard_deviation=np.sqrt(annualised_variance)
standard_deviation
# Out:
# Ticker
# BANDHANBNK.NS    0.292337
# COROMANDEL.NS    0.218687
# DIVISLAB.NS      0.279066
# FORTIS.NS        0.235367
# GILLETTE.NS      0.231048
# NCC.NS           0.405623
# RECLTD.NS        0.370426
# SPY              0.135808
# dtype: float64

# %% [markdown]
# ## Minimum Variance Portfolio

# %%
min_variance=100
er=[]
sigma=[]
sharpe_ratio=0
min_weights=np.ones(8)
for i in range(0,100000):
    x,y,z=make_random_portfolio(8,annualised_mean_returns,cov_matrix)
    er.append(y)
    sigma.append(np.sqrt(z))
    if(z<min_variance):
        min_variance=z
        min_weights=x
        min_return=y
    sharpe_temp=(y-risk_free_rate)/np.sqrt(z)
    if(sharpe_temp>sharpe_ratio):
        sharpe_ratio=sharpe_temp
        sharpe_weights=x
        sharpe_return=y
        sharpe_variance=z

# %%
print(f"min_var_weights: {min_weights}")
print(f"min_var_return: {min_return}")
print(f"min_variance: {min_variance}")
print(f"max_sharpe_ratio: {sharpe_ratio}")
print(f"max_sharpe_weights: {sharpe_weights}")
print(f"max_sharpe_return: {sharpe_return}")
print(f"max_sharpe_variance: {sharpe_variance}")
# Out:
# min_var_weights: [ 0.11815542  0.09037352  0.0318504   0.14294433  0.18285271 -0.0107683
#   0.11370929  0.33088263]
# min_var_return: 0.6035396621096034
# min_variance: 0.011724485527544478
# max_sharpe_ratio: 8.304577120091414
# max_sharpe_weights: [-0.45061643 -0.00637415 -0.01951206  0.19566237  0.11261829  0.0330877
#   0.76702435  0.36810993]
# max_sharpe_return: 2.5266168055653164
# max_sharpe_variance: 0.08759903318891775

# %% [markdown]
# ## Efficient Frontier and Tangency Portfolio

# %%
plt.figure(figsize=(10,10))
plt.scatter(sigma,er)
plt.scatter(np.sqrt(sharpe_variance),sharpe_return,c="r")
plt.scatter(np.sqrt(min_variance),min_return, c='y')


plt.annotate('Tangency Portfolio', 
             xy=(np.sqrt(sharpe_variance),sharpe_return), 
             xytext=(np.sqrt(sharpe_variance) + 0.01,sharpe_return + 0.01),
             fontsize=10)

plt.annotate('Minimum Variance', 
             xy=(np.sqrt(min_variance),min_return), 
             xytext=(np.sqrt(min_variance) + 0.01,min_return + 0.01),
             fontsize=10)


x = np.linspace(0, max(sigma), 100)
y = risk_free_rate + sharpe_ratio * x
plt.title("Efficient Frontier and Tangency Portfolio, Domestic + SPY")
plt.xlabel('Portfolio Risk (Standard Deviation)')
plt.ylabel('Portfolio Return')
plt.plot(x,y,c='purple',label='CAL',linewidth=2)
plt.legend()

# %% [markdown]
# # International Portfolio with SPY and Bitcoin

# %%
df=data[[('Adj Close', 'BANDHANBNK.NS'),
            ('Adj Close',       'BTC-USD'),
            ('Adj Close', 'COROMANDEL.NS'),
            ('Adj Close',   'DIVISLAB.NS'),
            ('Adj Close',     'FORTIS.NS'),
            ('Adj Close',   'GILLETTE.NS'),
            ('Adj Close',        'NCC.NS'),
            ('Adj Close',     'RECLTD.NS'),
            ('Adj Close',           'SPY'),]]
df.dropna(inplace=True)
df
# Out:
# Price                         Adj Close                              \
# Ticker                    BANDHANBNK.NS       BTC-USD COROMANDEL.NS
# Date
# 2023-01-03 00:00:00+00:00    237.153839  16679.857422    880.080872
# 2023-01-04 00:00:00+00:00    236.710190  16863.238281    875.047974
# 2023-01-05 00:00:00+00:00    237.104553  16836.736328    882.133240
# 2023-01-06 00:00:00+00:00    238.928436  16951.968750    881.253662
# 2023-01-09 00:00:00+00:00    243.759247  17196.554688    878.615051
# ...                                 ...           ...           ...
# 2023-12-22 00:00:00+00:00    233.012634  43997.902344   1226.509277
# 2023-12-26 00:00:00+00:00    233.161484  42520.402344   1258.540527
# 2023-12-27 00:00:00+00:00    236.188278  43442.855469   1238.066406
# 2023-12-28 00:00:00+00:00    237.528000  42627.855469   1235.177124
# 2023-12-29 00:00:00+00:00    239.562393  42099.402344   1247.033203
#
# Price                                                                        \
# Ticker                     DIVISLAB.NS   FORTIS.NS  GILLETTE.NS      NCC.NS
# Date
# 2023-01-03 00:00:00+00:00  3318.440918  282.157806  4908.235840   87.477234
# 2023-01-04 00:00:00+00:00  3360.055908  281.809570  4921.987305   87.959732
# 2023-01-05 00:00:00+00:00  3385.778076  285.639984  4911.955566   89.986244
# 2023-01-06 00:00:00+00:00  3359.419922  283.401459  4890.032715   90.854736
# 2023-01-09 00:00:00+00:00  3383.479736  285.789246  4872.661133   90.275734
# ...                                ...         ...          ...         ...
# 2023-12-22 00:00:00+00:00  3672.410156  389.898071  6100.717285  162.872147
# 2023-12-26 00:00:00+00:00  3839.931885  395.286987  6060.233398  166.348083
# 2023-12-27 00:00:00+00:00  3860.555420  399.378571  6071.409668  167.241882
# 2023-12-28 00:00:00+00:00  3915.915527  404.468079  6507.246582  165.603241
# 2023-12-29 00:00:00+00:00  3880.085449  418.339600  6440.435547  165.603241
#
# Price
# Ticker                      RECLTD.NS         SPY
# Date
# 2023-01-03 00:00:00+00:00  110.857712  371.614441
# 2023-01-04 00:00:00+00:00  110.136681  374.483337
# 2023-01-05 00:00:00+00:00  111.623802  370.209229
# 2023-01-06 00:00:00+00:00  111.488602  378.698883
# 2023-01-09 00:00:00+00:00  113.155975  378.484192
# ...                               ...         ...
# 2023-12-22 00:00:00+00:00  396.268372  469.225250
# 2023-12-26 00:00:00+00:00  408.353302  471.206573
# 2023-12-27 00:00:00+00:00  400.069305  472.058533
# 2023-12-28 00:00:00+00:00  399.825653  472.236847
# 2023-12-29 00:00:00+00:00  402.359589  470.869720
#
# [237 rows x 9 columns]

# %%
returns = np.log(df / df.shift(1)).dropna()
returns.columns = returns.columns.get_level_values(1)
mean_returns = returns.mean()
annualised_mean_returns=(1+mean_returns)**252 -1
annualised_mean_returns
# Out:
# Ticker
# BANDHANBNK.NS    0.010848
# BTC-USD          1.682276
# COROMANDEL.NS    0.450433
# DIVISLAB.NS      0.181645
# FORTIS.NS        0.522230
# GILLETTE.NS      0.336339
# NCC.NS           0.974994
# RECLTD.NS        2.946186
# SPY              0.287429
# dtype: float64

# %%
cov_matrix = returns.cov()
cov_matrix*252
# Out:
# Ticker         BANDHANBNK.NS   BTC-USD  COROMANDEL.NS  DIVISLAB.NS  FORTIS.NS  \
# Ticker
# BANDHANBNK.NS       0.085461 -0.011813       0.019657     0.006365   0.006987
# BTC-USD            -0.011813  0.221550      -0.018395    -0.010655  -0.012494
# COROMANDEL.NS       0.019657 -0.018395       0.047824     0.010484   0.004005
# DIVISLAB.NS         0.006365 -0.010655       0.010484     0.077878   0.011238
# FORTIS.NS           0.006987 -0.012494       0.004005     0.011238   0.055398
# GILLETTE.NS         0.000122 -0.011423       0.005003     0.006428   0.006192
# NCC.NS              0.017650 -0.028464       0.015352    -0.004203   0.005161
# RECLTD.NS           0.032792 -0.007085       0.021629     0.002000   0.011497
# SPY                -0.000936  0.011834      -0.000090     0.001765   0.000745
#
# Ticker         GILLETTE.NS    NCC.NS  RECLTD.NS       SPY
# Ticker
# BANDHANBNK.NS     0.000122  0.017650   0.032792 -0.000936
# BTC-USD          -0.011423 -0.028464  -0.007085  0.011834
# COROMANDEL.NS     0.005003  0.015352   0.021629 -0.000090
# DIVISLAB.NS       0.006428 -0.004203   0.002000  0.001765
# FORTIS.NS         0.006192  0.005161   0.011497  0.000745
# GILLETTE.NS       0.053383  0.002037   0.001845 -0.000437
# NCC.NS            0.002037  0.164530   0.042496  0.003698
# RECLTD.NS         0.001845  0.042496   0.137215  0.003359
# SPY              -0.000437  0.003698   0.003359  0.018444

# %%
variance=returns.var()
variance
annualised_variance=variance*252
standard_deviation=np.sqrt(annualised_variance)
standard_deviation
# Out:
# Ticker
# BANDHANBNK.NS    0.292337
# BTC-USD          0.470691
# COROMANDEL.NS    0.218687
# DIVISLAB.NS      0.279066
# FORTIS.NS        0.235367
# GILLETTE.NS      0.231048
# NCC.NS           0.405623
# RECLTD.NS        0.370426
# SPY              0.135808
# dtype: float64

# %% [markdown]
# ## Minimum Variance Portfolio

# %%
min_variance=100
er=[]
sigma=[]
sharpe_ratio=0
min_weights=np.ones(9)
for i in range(0,100000):
    x,y,z=make_random_portfolio(9,annualised_mean_returns,cov_matrix)
    er.append(y)
    sigma.append(np.sqrt(z))
    if(z<min_variance):
        min_variance=z
        min_weights=x
        min_return=y
    sharpe_temp=(y-risk_free_rate)/np.sqrt(z)
    if(sharpe_temp>sharpe_ratio):
        sharpe_ratio=sharpe_temp
        sharpe_weights=x
        sharpe_return=y
        sharpe_variance=z

# %%
print(f"min_var_weights: {min_weights}")
print(f"min_var_return: {min_return}")
print(f"min_variance: {min_variance}")
print(f"max_sharpe_ratio: {sharpe_ratio}")
print(f"max_sharpe_weights: {sharpe_weights}")
print(f"max_sharpe_return: {sharpe_return}")
print(f"max_sharpe_variance: {sharpe_variance}")
# Out:
# min_var_weights: [ 0.08517404  0.03234338  0.20612744  0.10604085  0.13337519  0.09373378
#   0.09882571 -0.01729668  0.26167628]
# min_var_return: 0.38923028827821204
# min_variance: 0.010812586437486851
# max_sharpe_ratio: 8.929946193485296
# max_sharpe_weights: [-0.42555972  0.25242531 -0.05714691  0.06936245  0.22384176  0.11014117
#   0.15720636  0.62790799  0.04182159]
# max_sharpe_return: 2.576062336309457
# max_sharpe_variance: 0.07883816579566451

# %% [markdown]
# ## Efficient Frontier and Tangency Portfolio

# %%
plt.figure(figsize=(10,10))
plt.scatter(sigma,er)
plt.scatter(np.sqrt(sharpe_variance),sharpe_return,c="r")
plt.scatter(np.sqrt(min_variance),min_return, c='y')


plt.annotate('Tangency Portfolio', 
             xy=(np.sqrt(sharpe_variance),sharpe_return), 
             xytext=(np.sqrt(sharpe_variance) + 0.01,sharpe_return + 0.01),
             fontsize=10)

plt.annotate('Minimum Variance', 
             xy=(np.sqrt(min_variance),min_return), 
             xytext=(np.sqrt(min_variance) + 0.01,min_return + 0.01),
             fontsize=10)


x = np.linspace(0, max(sigma), 100)
y = risk_free_rate + sharpe_ratio * x
plt.title("Efficient Frontier and Tangency Portfolio, Domestic + SPY + BTC")
plt.xlabel('Portfolio Risk (Standard Deviation)')
plt.ylabel('Portfolio Return')
plt.plot(x,y,c='purple',label='CAL',linewidth=2)
plt.legend()
