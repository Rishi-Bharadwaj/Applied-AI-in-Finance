# %%
import pandas as pd
import numpy as np
import yfinance as yf

data = yf.download("GILLETTE.NS NCC.NS FORTIS.NS RECLTD.NS DIVISLAB.NS COROMANDEL.NS", period="1y")
data
# Out:
# [*********************100%***********************]  6 of 6 completed
# Price                         Adj Close                                        \
# Ticker                    COROMANDEL.NS  DIVISLAB.NS   FORTIS.NS  GILLETTE.NS
# Date
# 2023-10-16 00:00:00+00:00   1150.341187  3632.902588  336.507904  6202.546387
# 2023-10-17 00:00:00+00:00   1157.414917  3624.355225  336.757385  6180.943359
# 2023-10-18 00:00:00+00:00   1155.820801  3618.988037  335.060852  6160.327148
# 2023-10-19 00:00:00+00:00   1155.771118  3615.559082  333.114838  6225.431152
# 2023-10-20 00:00:00+00:00   1133.553345  3532.618164  331.518158  6222.176270
# ...                                 ...          ...         ...          ...
# 2024-10-09 00:00:00+00:00   1610.550049  5989.750000  607.450012  8995.849609
# 2024-10-10 00:00:00+00:00   1628.050049  5942.149902  614.400024  8952.000000
# 2024-10-11 00:00:00+00:00   1638.949951  6142.250000  600.299988  9023.549805
# ...

# %%
data.columns
# Out:
# MultiIndex([('Adj Close', 'COROMANDEL.NS'),
#             ('Adj Close',   'DIVISLAB.NS'),
#             ('Adj Close',     'FORTIS.NS'),
#             ('Adj Close',   'GILLETTE.NS'),
#             ('Adj Close',        'NCC.NS'),
#             ('Adj Close',     'RECLTD.NS'),
#             (    'Close', 'COROMANDEL.NS'),
#             (    'Close',   'DIVISLAB.NS'),
#             (    'Close',     'FORTIS.NS'),
#             (    'Close',   'GILLETTE.NS'),
#             (    'Close',        'NCC.NS'),
#             (    'Close',     'RECLTD.NS'),
#             (     'High', 'COROMANDEL.NS'),
#             (     'High',   'DIVISLAB.NS'),
#             (     'High',     'FORTIS.NS'),
#             (     'High',   'GILLETTE.NS'),
#             (     'High',        'NCC.NS'),
#             (     'High',     'RECLTD.NS'),
#             (      'Low', 'COROMANDEL.NS'),
#             (      'Low',   'DIVISLAB.NS'),
#             (      'Low',     'FORTIS.NS'),
# ...

# %%
data=data[[('Adj Close', 'COROMANDEL.NS'),
            ('Adj Close',   'DIVISLAB.NS'),
            ('Adj Close',     'FORTIS.NS'),
            ('Adj Close',   'GILLETTE.NS'),
            ('Adj Close',        'NCC.NS'),
            ('Adj Close',     'RECLTD.NS'),]]
data
# Out:
# Price                         Adj Close                                        \
# Ticker                    COROMANDEL.NS  DIVISLAB.NS   FORTIS.NS  GILLETTE.NS
# Date
# 2023-10-16 00:00:00+00:00   1150.341187  3632.902588  336.507904  6202.546387
# 2023-10-17 00:00:00+00:00   1157.414917  3624.355225  336.757385  6180.943359
# 2023-10-18 00:00:00+00:00   1155.820801  3618.988037  335.060852  6160.327148
# 2023-10-19 00:00:00+00:00   1155.771118  3615.559082  333.114838  6225.431152
# 2023-10-20 00:00:00+00:00   1133.553345  3532.618164  331.518158  6222.176270
# ...                                 ...          ...         ...          ...
# 2024-10-09 00:00:00+00:00   1610.550049  5989.750000  607.450012  8995.849609
# 2024-10-10 00:00:00+00:00   1628.050049  5942.149902  614.400024  8952.000000
# 2024-10-11 00:00:00+00:00   1638.949951  6142.250000  600.299988  9023.549805
# 2024-10-14 00:00:00+00:00   1626.099976  6214.850098  597.700012  9055.299805
# ...
